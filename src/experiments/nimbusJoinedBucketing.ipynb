# %% [markdown]
# # Preparation

# %% [markdown]
# ## 设置CWD

# %%
import os
import sys
print(os.path.abspath(''))

workspace_path = os.path.abspath('')

# 去到最近的有.git的父目录
while not os.path.exists(os.path.join(workspace_path, '.git')):
    workspace_path = os.path.join(workspace_path, '..')
    if os.path.exists(os.path.join(workspace_path, '.git')):
        break

os.chdir(workspace_path)
print("current working directory: ", os.getcwd())
sys.path.append(os.path.join(workspace_path, 'src'))
# Out:
# /home/futou/projects/cumulonimbus/nimbus/src/experiments
# current working directory:  /home/futou/projects/cumulonimbus/nimbus

# %% [markdown]
# ## Load Data

# %%
import torch
# import modules
import numpy as np

checkpoint = torch.load('saves/model_checkpoints/Perceptron2-test_4/RsltChk-latest.pth')
weight = checkpoint['linear3.weight']

print(weight)

input = np.load('saves/input_cache/input_nimbus_linear_2_latest.npy')
print(weight.shape, input.shape)
# Out:
# tensor([[ 3.7710e-41,  6.3988e-04,  8.2470e-01,  4.0351e-01, -1.5783e-01,
#           2.6596e-01, -2.8826e-01,  9.2024e-04, -6.5420e-01, -6.0282e-01,
#           2.4770e-01,  3.1837e-01,  3.4833e-01,  6.0645e-01,  1.6137e-01,
#          -6.4354e-01,  4.5205e-01, -1.2689e-01, -5.5237e-01, -9.7803e-01,
#           1.0098e+00,  9.8068e-02, -6.7403e-02,  3.8855e-20, -1.9476e-02,
#           8.8891e-01,  3.1627e-01,  2.2169e-41, -7.6105e-01, -1.0805e-03,
#           4.3923e-01,  4.0121e-41],
#         [ 5.6914e-41, -8.7278e-05, -3.9147e-01, -5.5920e-01,  9.6399e-01,
#           4.2181e-01,  6.6338e-01,  1.0713e-03,  1.1602e+00,  2.3408e-01,
#          -1.1428e+00, -3.5919e-01, -1.4835e-02, -7.3594e-01, -6.7426e-01,
#           3.3176e-01,  3.2221e-01, -6.1217e-01,  3.1218e-01,  3.5569e-01,
#          -4.8062e-01,  2.2023e-01, -6.6901e-01,  1.5731e-23, -3.1300e-01,
#          -8.2487e-01,  3.6663e-01, -2.4988e-41,  3.5329e-01, -6.2666e-03,
#           2.2560e-01,  1.7837e-41],
#         [ 6.2192e-41, -3.9210e-04, -4.9183e-01,  1.2195e-01, -8.5260e-01,
#          -6.6037e-01, -2.4083e-01,  9.3496e-06, -5.2750e-01,  3.9856e-01,
#           6.1174e-01,  7.9216e-02, -2.2432e-01,  1.2594e-01,  4.6730e-01,
#           2.8874e-01, -8.7570e-01,  7.7419e-01,  2.9361e-01,  5.4690e-01,
#          -4.9237e-01, -3.0977e-01,  7.6281e-01, -1.5512e-19,  3.1568e-01,
#          -4.4106e-02, -7.7437e-01,  1.1729e-36,  4.2713e-01,  1.0861e-02,
#          -6.4648e-01,  1.3396e-41]], device='cuda:0')
# torch.Size([3, 32]) (406536, 32)

# %%
import arg_settings
import modules

# create layer
layerJB = modules.NimbusLinearJoinedBucketing(32, 3, False, codeblockCount=16, treeDepth=4)
print(layerJB.weight)
layerJB.weight.data = weight
# Out:
# target min tensor(0) target max tensor(2)
# start nimbus linear init, in_features: 14 out_features: 32 bias: False state: 1 codeblockCount: -1 treeDepth: 4
# start nimbus linear init, in_features: 32 out_features: 32 bias: False state: 1 codeblockCount: -1 treeDepth: 4
# start nimbus linear init, in_features: 32 out_features: 3 bias: False state: 1 codeblockCount: -1 treeDepth: 4
# start nimbus linear init, in_features: 32 out_features: 3 bias: False state: 1 codeblockCount: 16 treeDepth: 4
# Parameter containing:
# tensor([[-0.0861,  0.0397, -0.0253, -0.1164,  0.0545, -0.0119, -0.0891, -0.1265,
#           0.1373, -0.1693,  0.0258, -0.1384,  0.0781, -0.1726,  0.1323,  0.0948,
#           0.0619, -0.0198, -0.0538,  0.1616,  0.0794, -0.1492,  0.0189,  0.0354,
#          -0.0191,  0.1416, -0.0158, -0.0812, -0.1133, -0.1024, -0.0052,  0.0791],
#         [ 0.0353,  0.0241,  0.0795, -0.0234,  0.1196,  0.1584, -0.1426,  0.0672,
#           0.1580, -0.0660,  0.1501,  0.1284, -0.0501, -0.1739, -0.1447, -0.1625,
#           0.1205, -0.1424,  0.1655,  0.1595, -0.0672, -0.0071, -0.0423,  0.1191,
#          -0.1143, -0.1379, -0.1128,  0.1000,  0.1335,  0.1346,  0.1704,  0.1269],
#         [-0.0294, -0.1471, -0.0260,  0.1153, -0.0258,  0.1424,  0.1686, -0.0765,
#           0.1299,  0.0593, -0.1306, -0.0210, -0.1207,  0.1319, -0.1261,  0.1644,
#           0.1322, -0.0233, -0.1349,  0.1077, -0.0872, -0.1023,  0.1712, -0.1218,
#          -0.0752, -0.0519, -0.0614, -0.0753,  0.1584,  0.0742, -0.1113,  0.1028]],
#        requires_grad=True)

# %%
layerJB.weight
# Out:
# Parameter containing:
# tensor([[ 3.7710e-41,  6.3988e-04,  8.2470e-01,  4.0351e-01, -1.5783e-01,
#           2.6596e-01, -2.8826e-01,  9.2024e-04, -6.5420e-01, -6.0282e-01,
#           2.4770e-01,  3.1837e-01,  3.4833e-01,  6.0645e-01,  1.6137e-01,
#          -6.4354e-01,  4.5205e-01, -1.2689e-01, -5.5237e-01, -9.7803e-01,
#           1.0098e+00,  9.8068e-02, -6.7403e-02,  3.8855e-20, -1.9476e-02,
#           8.8891e-01,  3.1627e-01,  2.2169e-41, -7.6105e-01, -1.0805e-03,
#           4.3923e-01,  4.0121e-41],
#         [ 5.6914e-41, -8.7278e-05, -3.9147e-01, -5.5920e-01,  9.6399e-01,
#           4.2181e-01,  6.6338e-01,  1.0713e-03,  1.1602e+00,  2.3408e-01,
#          -1.1428e+00, -3.5919e-01, -1.4835e-02, -7.3594e-01, -6.7426e-01,
#           3.3176e-01,  3.2221e-01, -6.1217e-01,  3.1218e-01,  3.5569e-01,
#          -4.8062e-01,  2.2023e-01, -6.6901e-01,  1.5731e-23, -3.1300e-01,
#          -8.2487e-01,  3.6663e-01, -2.4988e-41,  3.5329e-01, -6.2666e-03,
#           2.2560e-01,  1.7837e-41],
#         [ 6.2192e-41, -3.9210e-04, -4.9183e-01,  1.2195e-01, -8.5260e-01,
#          -6.6037e-01, -2.4083e-01,  9.3496e-06, -5.2750e-01,  3.9856e-01,
#           6.1174e-01,  7.9216e-02, -2.2432e-01,  1.2594e-01,  4.6730e-01,
#           2.8874e-01, -8.7570e-01,  7.7419e-01,  2.9361e-01,  5.4690e-01,
#          -4.9237e-01, -3.0977e-01,  7.6281e-01, -1.5512e-19,  3.1568e-01,
#          -4.4106e-02, -7.7437e-01,  1.1729e-36,  4.2713e-01,  1.0861e-02,
#          -6.4648e-01,  1.3396e-41]], device='cuda:0', requires_grad=True)

# %%
# 运行learn maddness joined，查看lut和simple lut avg的差别
layerJB.learn_maddness_params(input)
# Out:
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:1, threshold:0.5186643004417419, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (298669, 2) & bucket id 2 with length (107867, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:1, threshold:0.17207971215248108, from bucket_id:1's shape (298669, 2), to bucket id 3 with length (259415, 2) & bucket id 4 with length (39254, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:1, threshold:0.056539520621299744, from bucket_id:3's shape (259415, 2), to bucket id 7 with length (237404, 2) & bucket id 8 with length (22011, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:1, threshold:0.01841186359524727, from bucket_id:7's shape (237404, 2), to bucket id 15 with length (230545, 2) & bucket id 16 with length (6859, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:1, threshold:0.11210529506206512, from bucket_id:8's shape (22011, 2), to bucket id 17 with length (11087, 2) & bucket id 18 with length (10924, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:1, threshold:0.3394405245780945, from bucket_id:4's shape (39254, 2), to bucket id 9 with length (21093, 2) & bucket id 10 with length (18161, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:1, threshold:0.25401902198791504, from bucket_id:9's shape (21093, 2), to bucket id 19 with length (11367, 2) & bucket id 20 with length (9726, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:1, threshold:0.4297952651977539, from bucket_id:10's shape (18161, 2), to bucket id 21 with length (9413, 2) & bucket id 22 with length (8748, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:1, threshold:1.3167774677276611, from bucket_id:2's shape (107867, 2), to bucket id 5 with length (94041, 2) & bucket id 6 with length (13826, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:1, threshold:0.8826362490653992, from bucket_id:5's shape (94041, 2), to bucket id 11 with length (50033, 2) & bucket id 12 with length (44008, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:0.6846603751182556, from bucket_id:11's shape (50033, 2), to bucket id 23 with length (21251, 2) & bucket id 24 with length (28782, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:1, threshold:1.0713794231414795, from bucket_id:12's shape (44008, 2), to bucket id 25 with length (23435, 2) & bucket id 26 with length (20573, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:1, threshold:2.22808575630188, from bucket_id:6's shape (13826, 2), to bucket id 13 with length (11970, 2) & bucket id 14 with length (1856, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:1, threshold:1.6915407180786133, from bucket_id:13's shape (11970, 2), to bucket id 27 with length (8699, 2) & bucket id 28 with length (3271, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:1, threshold:3.087480068206787, from bucket_id:14's shape (1856, 2), to bucket id 29 with length (1270, 2) & bucket id 30 with length (586, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:1.1289901733398438, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (336027, 2) & bucket id 2 with length (70509, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:1, threshold:0.8120740056037903, from bucket_id:1's shape (336027, 2), to bucket id 3 with length (266608, 2) & bucket id 4 with length (69419, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.2938796281814575, from bucket_id:3's shape (266608, 2), to bucket id 7 with length (219557, 2) & bucket id 8 with length (47051, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:1, threshold:0.2484358549118042, from bucket_id:7's shape (219557, 2), to bucket id 15 with length (184383, 2) & bucket id 16 with length (35174, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.7295676469802856, from bucket_id:8's shape (47051, 2), to bucket id 17 with length (32072, 2) & bucket id 18 with length (14979, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:1, threshold:2.2985727787017822, from bucket_id:4's shape (69419, 2), to bucket id 9 with length (58098, 2) & bucket id 10 with length (11321, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.42226532101631165, from bucket_id:9's shape (58098, 2), to bucket id 19 with length (44726, 2) & bucket id 20 with length (13372, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:1, threshold:3.289947509765625, from bucket_id:10's shape (11321, 2), to bucket id 21 with length (8046, 2) & bucket id 22 with length (3275, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:1, threshold:1.4843008518218994, from bucket_id:2's shape (70509, 2), to bucket id 5 with length (52438, 2) & bucket id 6 with length (18071, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:2.3937501907348633, from bucket_id:5's shape (52438, 2), to bucket id 11 with length (46795, 2) & bucket id 12 with length (5643, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:0.5079522728919983, from bucket_id:11's shape (46795, 2), to bucket id 23 with length (25132, 2) & bucket id 24 with length (21663, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:0, threshold:4.384845733642578, from bucket_id:12's shape (5643, 2), to bucket id 25 with length (5340, 2) & bucket id 26 with length (303, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:2.619814872741699, from bucket_id:6's shape (18071, 2), to bucket id 13 with length (12660, 2) & bucket id 14 with length (5411, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:1, threshold:2.359605550765991, from bucket_id:13's shape (12660, 2), to bucket id 27 with length (4570, 2) & bucket id 28 with length (8090, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:3.588853359222412, from bucket_id:14's shape (5411, 2), to bucket id 29 with length (4121, 2) & bucket id 30 with length (1290, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:1.4809622764587402, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (346105, 2) & bucket id 2 with length (60431, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:1, threshold:1.446709156036377, from bucket_id:1's shape (346105, 2), to bucket id 3 with length (302655, 2) & bucket id 4 with length (43450, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.643873393535614, from bucket_id:3's shape (302655, 2), to bucket id 7 with length (220761, 2) & bucket id 8 with length (81894, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:1, threshold:0.589701771736145, from bucket_id:7's shape (220761, 2), to bucket id 15 with length (163070, 2) & bucket id 16 with length (57691, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:1.0592973232269287, from bucket_id:8's shape (81894, 2), to bucket id 17 with length (46724, 2) & bucket id 18 with length (35170, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:0.7238577604293823, from bucket_id:4's shape (43450, 2), to bucket id 9 with length (33495, 2) & bucket id 10 with length (9955, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:1, threshold:2.4090256690979004, from bucket_id:9's shape (33495, 2), to bucket id 19 with length (21979, 2) & bucket id 20 with length (11516, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:1, threshold:2.2003989219665527, from bucket_id:10's shape (9955, 2), to bucket id 21 with length (5423, 2) & bucket id 22 with length (4532, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:1.864295482635498, from bucket_id:2's shape (60431, 2), to bucket id 5 with length (24731, 2) & bucket id 6 with length (35700, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:1, threshold:0.8641000986099243, from bucket_id:5's shape (24731, 2), to bucket id 11 with length (17958, 2) & bucket id 12 with length (6773, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:0.3552587926387787, from bucket_id:11's shape (17958, 2), to bucket id 23 with length (13064, 2) & bucket id 24 with length (4894, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:1, threshold:2.2699599266052246, from bucket_id:12's shape (6773, 2), to bucket id 25 with length (5271, 2) & bucket id 26 with length (1502, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:3.893449306488037, from bucket_id:6's shape (35700, 2), to bucket id 13 with length (32841, 2) & bucket id 14 with length (2859, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:1, threshold:1.633392333984375, from bucket_id:13's shape (32841, 2), to bucket id 27 with length (25858, 2) & bucket id 28 with length (6983, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:4.912039756774902, from bucket_id:14's shape (2859, 2), to bucket id 29 with length (1657, 2) & bucket id 30 with length (1202, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:0.7183753252029419, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (234355, 2) & bucket id 2 with length (172181, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:0, threshold:0.25796011090278625, from bucket_id:1's shape (234355, 2), to bucket id 3 with length (192057, 2) & bucket id 4 with length (42298, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.07820239663124084, from bucket_id:3's shape (192057, 2), to bucket id 7 with length (162639, 2) & bucket id 8 with length (29418, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.02681678906083107, from bucket_id:7's shape (162639, 2), to bucket id 15 with length (155045, 2) & bucket id 16 with length (7594, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.15447735786437988, from bucket_id:8's shape (29418, 2), to bucket id 17 with length (15102, 2) & bucket id 18 with length (14316, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:0.48945361375808716, from bucket_id:4's shape (42298, 2), to bucket id 9 with length (21165, 2) & bucket id 10 with length (21133, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.37115076184272766, from bucket_id:9's shape (21165, 2), to bucket id 19 with length (9620, 2) & bucket id 20 with length (11545, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:0.6076129674911499, from bucket_id:10's shape (21133, 2), to bucket id 21 with length (11208, 2) & bucket id 22 with length (9925, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:1.64552903175354, from bucket_id:2's shape (172181, 2), to bucket id 5 with length (134624, 2) & bucket id 6 with length (37557, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:1.1509859561920166, from bucket_id:5's shape (134624, 2), to bucket id 11 with length (88385, 2) & bucket id 12 with length (46239, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:0, threshold:0.9215354919433594, from bucket_id:11's shape (88385, 2), to bucket id 23 with length (38871, 2) & bucket id 24 with length (49514, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:0, threshold:1.3763937950134277, from bucket_id:12's shape (46239, 2), to bucket id 25 with length (25727, 2) & bucket id 26 with length (20512, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:2.514892578125, from bucket_id:6's shape (37557, 2), to bucket id 13 with length (30757, 2) & bucket id 14 with length (6800, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:2.0139834880828857, from bucket_id:13's shape (30757, 2), to bucket id 27 with length (13842, 2) & bucket id 28 with length (16915, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:3.3358922004699707, from bucket_id:14's shape (6800, 2), to bucket id 29 with length (5640, 2) & bucket id 30 with length (1160, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:1.4649178981781006, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (336669, 2) & bucket id 2 with length (69867, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:0, threshold:0.49063342809677124, from bucket_id:1's shape (336669, 2), to bucket id 3 with length (208783, 2) & bucket id 4 with length (127886, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:1, threshold:0.5618966817855835, from bucket_id:3's shape (208783, 2), to bucket id 7 with length (136628, 2) & bucket id 8 with length (72155, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.17743456363677979, from bucket_id:7's shape (136628, 2), to bucket id 15 with length (124440, 2) & bucket id 16 with length (12188, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:1, threshold:5.554131031036377, from bucket_id:8's shape (72155, 2), to bucket id 17 with length (71848, 2) & bucket id 18 with length (307, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:0.9660157561302185, from bucket_id:4's shape (127886, 2), to bucket id 9 with length (77681, 2) & bucket id 10 with length (50205, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.7549203634262085, from bucket_id:9's shape (77681, 2), to bucket id 19 with length (47439, 2) & bucket id 20 with length (30242, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:1.2149155139923096, from bucket_id:10's shape (50205, 2), to bucket id 21 with length (26702, 2) & bucket id 22 with length (23503, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:2.9013538360595703, from bucket_id:2's shape (69867, 2), to bucket id 5 with length (47289, 2) & bucket id 6 with length (22578, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:1.9616122245788574, from bucket_id:5's shape (47289, 2), to bucket id 11 with length (29671, 2) & bucket id 12 with length (17618, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:0, threshold:1.7208483219146729, from bucket_id:11's shape (29671, 2), to bucket id 23 with length (18295, 2) & bucket id 24 with length (11376, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:0, threshold:2.3731589317321777, from bucket_id:12's shape (17618, 2), to bucket id 25 with length (12854, 2) & bucket id 26 with length (4764, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:3.981213092803955, from bucket_id:6's shape (22578, 2), to bucket id 13 with length (13089, 2) & bucket id 14 with length (9489, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:3.4787135124206543, from bucket_id:13's shape (13089, 2), to bucket id 27 with length (7044, 2) & bucket id 28 with length (6045, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:4.746119499206543, from bucket_id:14's shape (9489, 2), to bucket id 29 with length (7218, 2) & bucket id 30 with length (2271, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:1.1938860416412354, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (330496, 2) & bucket id 2 with length (76040, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:1, threshold:0.9442274570465088, from bucket_id:1's shape (330496, 2), to bucket id 3 with length (281397, 2) & bucket id 4 with length (49099, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.3967301845550537, from bucket_id:3's shape (281397, 2), to bucket id 7 with length (272693, 2) & bucket id 8 with length (8704, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:1, threshold:0.23560447990894318, from bucket_id:7's shape (272693, 2), to bucket id 15 with length (242397, 2) & bucket id 16 with length (30296, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.7890137434005737, from bucket_id:8's shape (8704, 2), to bucket id 17 with length (4805, 2) & bucket id 18 with length (3899, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:0.3201485872268677, from bucket_id:4's shape (49099, 2), to bucket id 9 with length (41096, 2) & bucket id 10 with length (8003, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:1, threshold:2.0889058113098145, from bucket_id:9's shape (41096, 2), to bucket id 19 with length (26931, 2) & bucket id 20 with length (14165, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:1, threshold:2.718972682952881, from bucket_id:10's shape (8003, 2), to bucket id 21 with length (5281, 2) & bucket id 22 with length (2722, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:2.703000068664551, from bucket_id:2's shape (76040, 2), to bucket id 5 with length (42086, 2) & bucket id 6 with length (33954, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:2.018735408782959, from bucket_id:5's shape (42086, 2), to bucket id 11 with length (26812, 2) & bucket id 12 with length (15274, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:1.976801872253418, from bucket_id:11's shape (26812, 2), to bucket id 23 with length (24905, 2) & bucket id 24 with length (1907, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:1, threshold:1.8762273788452148, from bucket_id:12's shape (15274, 2), to bucket id 25 with length (14454, 2) & bucket id 26 with length (820, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:3.7941293716430664, from bucket_id:6's shape (33954, 2), to bucket id 13 with length (24372, 2) & bucket id 14 with length (9582, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:3.2128214836120605, from bucket_id:13's shape (24372, 2), to bucket id 27 with length (13143, 2) & bucket id 28 with length (11229, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:1, threshold:1.5561978816986084, from bucket_id:14's shape (9582, 2), to bucket id 29 with length (6176, 2) & bucket id 30 with length (3406, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:1, threshold:0.8570748567581177, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (327922, 2) & bucket id 2 with length (78614, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:0, threshold:1.1229941844940186, from bucket_id:1's shape (327922, 2), to bucket id 3 with length (269326, 2) & bucket id 4 with length (58596, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:1, threshold:0.2986283302307129, from bucket_id:3's shape (269326, 2), to bucket id 7 with length (153541, 2) & bucket id 8 with length (115785, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.4173034429550171, from bucket_id:7's shape (153541, 2), to bucket id 15 with length (113059, 2) & bucket id 16 with length (40482, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:1, threshold:0.5418163537979126, from bucket_id:8's shape (115785, 2), to bucket id 17 with length (72415, 2) & bucket id 18 with length (43370, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:2.5030250549316406, from bucket_id:4's shape (58596, 2), to bucket id 9 with length (45335, 2) & bucket id 10 with length (13261, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:1, threshold:0.32050639390945435, from bucket_id:9's shape (45335, 2), to bucket id 19 with length (41838, 2) & bucket id 20 with length (3497, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:5.5186309814453125, from bucket_id:10's shape (13261, 2), to bucket id 21 with length (13000, 2) & bucket id 22 with length (261, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:1.1031055450439453, from bucket_id:2's shape (78614, 2), to bucket id 5 with length (62141, 2) & bucket id 6 with length (16473, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:1, threshold:1.8241089582443237, from bucket_id:5's shape (62141, 2), to bucket id 11 with length (53628, 2) & bucket id 12 with length (8513, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:1.3439544439315796, from bucket_id:11's shape (53628, 2), to bucket id 23 with length (25374, 2) & bucket id 24 with length (28254, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:1, threshold:2.364015579223633, from bucket_id:12's shape (8513, 2), to bucket id 25 with length (4869, 2) & bucket id 26 with length (3644, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:1, threshold:1.2466330528259277, from bucket_id:6's shape (16473, 2), to bucket id 13 with length (5331, 2) & bucket id 14 with length (11142, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:1.6879706382751465, from bucket_id:13's shape (5331, 2), to bucket id 27 with length (1122, 2) & bucket id 28 with length (4209, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:2.194082260131836, from bucket_id:14's shape (11142, 2), to bucket id 29 with length (6275, 2) & bucket id 30 with length (4867, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:0.7472255229949951, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (205582, 2) & bucket id 2 with length (200954, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:1, threshold:0.9286400079727173, from bucket_id:1's shape (205582, 2), to bucket id 3 with length (133267, 2) & bucket id 4 with length (72315, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:1, threshold:0.3565753102302551, from bucket_id:3's shape (133267, 2), to bucket id 7 with length (99604, 2) & bucket id 8 with length (33663, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.21454590559005737, from bucket_id:7's shape (99604, 2), to bucket id 15 with length (75347, 2) & bucket id 16 with length (24257, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.2003757357597351, from bucket_id:8's shape (33663, 2), to bucket id 17 with length (31639, 2) & bucket id 18 with length (2024, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:1, threshold:1.849832534790039, from bucket_id:4's shape (72315, 2), to bucket id 9 with length (49796, 2) & bucket id 10 with length (22519, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:1, threshold:1.4157462120056152, from bucket_id:9's shape (49796, 2), to bucket id 19 with length (20525, 2) & bucket id 20 with length (29271, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:1, threshold:2.41523814201355, from bucket_id:10's shape (22519, 2), to bucket id 21 with length (16335, 2) & bucket id 22 with length (6184, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:2.042160987854004, from bucket_id:2's shape (200954, 2), to bucket id 5 with length (139419, 2) & bucket id 6 with length (61535, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:1, threshold:0.8571858406066895, from bucket_id:5's shape (139419, 2), to bucket id 11 with length (122002, 2) & bucket id 12 with length (17417, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:0, threshold:1.398428201675415, from bucket_id:11's shape (122002, 2), to bucket id 23 with length (85879, 2) & bucket id 24 with length (36123, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:0, threshold:1.4630929231643677, from bucket_id:12's shape (17417, 2), to bucket id 25 with length (3680, 2) & bucket id 26 with length (13737, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:2.8062901496887207, from bucket_id:6's shape (61535, 2), to bucket id 13 with length (44271, 2) & bucket id 14 with length (17264, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:1, threshold:0.6763631105422974, from bucket_id:13's shape (44271, 2), to bucket id 27 with length (39667, 2) & bucket id 28 with length (4604, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:3.2631301879882812, from bucket_id:14's shape (17264, 2), to bucket id 29 with length (10339, 2) & bucket id 30 with length (6925, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:1.1146352291107178, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (320507, 2) & bucket id 2 with length (86029, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:1, threshold:0.5304653644561768, from bucket_id:1's shape (320507, 2), to bucket id 3 with length (155959, 2) & bucket id 4 with length (164548, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.28594669699668884, from bucket_id:3's shape (155959, 2), to bucket id 7 with length (112639, 2) & bucket id 8 with length (43320, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:1, threshold:0.1883462816476822, from bucket_id:7's shape (112639, 2), to bucket id 15 with length (99546, 2) & bucket id 16 with length (13093, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.7197809219360352, from bucket_id:8's shape (43320, 2), to bucket id 17 with length (28746, 2) & bucket id 18 with length (14574, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:1, threshold:1.237046718597412, from bucket_id:4's shape (164548, 2), to bucket id 9 with length (104988, 2) & bucket id 10 with length (59560, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.2984752655029297, from bucket_id:9's shape (104988, 2), to bucket id 19 with length (79309, 2) & bucket id 20 with length (25679, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:0.45492666959762573, from bucket_id:10's shape (59560, 2), to bucket id 21 with length (49554, 2) & bucket id 22 with length (10006, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:2.1088321208953857, from bucket_id:2's shape (86029, 2), to bucket id 5 with length (45646, 2) & bucket id 6 with length (40383, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:1, threshold:0.8996611833572388, from bucket_id:5's shape (45646, 2), to bucket id 11 with length (34726, 2) & bucket id 12 with length (10920, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:0.2620287537574768, from bucket_id:11's shape (34726, 2), to bucket id 23 with length (24432, 2) & bucket id 24 with length (10294, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:1, threshold:1.5376275777816772, from bucket_id:12's shape (10920, 2), to bucket id 25 with length (8361, 2) & bucket id 26 with length (2559, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:1, threshold:0.395879864692688, from bucket_id:6's shape (40383, 2), to bucket id 13 with length (28320, 2) & bucket id 14 with length (12063, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:3.001965045928955, from bucket_id:13's shape (28320, 2), to bucket id 27 with length (22862, 2) & bucket id 28 with length (5458, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:1, threshold:1.665725588798523, from bucket_id:14's shape (12063, 2), to bucket id 29 with length (10103, 2) & bucket id 30 with length (1960, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:1, threshold:0.35568878054618835, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (207582, 2) & bucket id 2 with length (198954, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:0, threshold:0.7993298768997192, from bucket_id:1's shape (207582, 2), to bucket id 3 with length (150636, 2) & bucket id 4 with length (56946, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.20416133105754852, from bucket_id:3's shape (150636, 2), to bucket id 7 with length (90584, 2) & bucket id 8 with length (60052, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:1, threshold:0.099112868309021, from bucket_id:7's shape (90584, 2), to bucket id 15 with length (79891, 2) & bucket id 16 with length (10693, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.4779183268547058, from bucket_id:8's shape (60052, 2), to bucket id 17 with length (26690, 2) & bucket id 18 with length (33362, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:1.7154136896133423, from bucket_id:4's shape (56946, 2), to bucket id 9 with length (48098, 2) & bucket id 10 with length (8848, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:1.2490589618682861, from bucket_id:9's shape (48098, 2), to bucket id 19 with length (30188, 2) & bucket id 20 with length (17910, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:2.789097309112549, from bucket_id:10's shape (8848, 2), to bucket id 21 with length (7471, 2) & bucket id 22 with length (1377, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:1, threshold:1.585183024406433, from bucket_id:2's shape (198954, 2), to bucket id 5 with length (150736, 2) & bucket id 6 with length (48218, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:1.7599281072616577, from bucket_id:5's shape (150736, 2), to bucket id 11 with length (142679, 2) & bucket id 12 with length (8057, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:0.9961193203926086, from bucket_id:11's shape (142679, 2), to bucket id 23 with length (86106, 2) & bucket id 24 with length (56573, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:1, threshold:0.5283889770507812, from bucket_id:12's shape (8057, 2), to bucket id 25 with length (2414, 2) & bucket id 26 with length (5643, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:1, threshold:1.9375030994415283, from bucket_id:6's shape (48218, 2), to bucket id 13 with length (24549, 2) & bucket id 14 with length (23669, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:0.5612642168998718, from bucket_id:13's shape (24549, 2), to bucket id 27 with length (23881, 2) & bucket id 28 with length (668, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:1, threshold:2.3970425128936768, from bucket_id:14's shape (23669, 2), to bucket id 29 with length (16335, 2) & bucket id 30 with length (7334, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:1.4124728441238403, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (369262, 2) & bucket id 2 with length (37274, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:1, threshold:0.9700791835784912, from bucket_id:1's shape (369262, 2), to bucket id 3 with length (293813, 2) & bucket id 4 with length (75449, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.4735407829284668, from bucket_id:3's shape (293813, 2), to bucket id 7 with length (264739, 2) & bucket id 8 with length (29074, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.10587416589260101, from bucket_id:7's shape (264739, 2), to bucket id 15 with length (237091, 2) & bucket id 16 with length (27648, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.8649317622184753, from bucket_id:8's shape (29074, 2), to bucket id 17 with length (11440, 2) & bucket id 18 with length (17634, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:0.5141191482543945, from bucket_id:4's shape (75449, 2), to bucket id 9 with length (58043, 2) & bucket id 10 with length (17406, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:1, threshold:2.7479045391082764, from bucket_id:9's shape (58043, 2), to bucket id 19 with length (36174, 2) & bucket id 20 with length (21869, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:1, threshold:3.9243383407592773, from bucket_id:10's shape (17406, 2), to bucket id 21 with length (15836, 2) & bucket id 22 with length (1570, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:4.052263259887695, from bucket_id:2's shape (37274, 2), to bucket id 5 with length (32263, 2) & bucket id 6 with length (5011, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:2.2649827003479004, from bucket_id:5's shape (32263, 2), to bucket id 11 with length (11751, 2) & bucket id 12 with length (20512, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:1.946427822113037, from bucket_id:11's shape (11751, 2), to bucket id 23 with length (5638, 2) & bucket id 24 with length (6113, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:1, threshold:1.7095838785171509, from bucket_id:12's shape (20512, 2), to bucket id 25 with length (9676, 2) & bucket id 26 with length (10836, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:5.743165016174316, from bucket_id:6's shape (5011, 2), to bucket id 13 with length (2888, 2) & bucket id 14 with length (2123, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:4.865679740905762, from bucket_id:13's shape (2888, 2), to bucket id 27 with length (2366, 2) & bucket id 28 with length (522, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:9.521432876586914, from bucket_id:14's shape (2123, 2), to bucket id 29 with length (2120, 2) & bucket id 30 with length (3, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:1.3429298400878906, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (306361, 2) & bucket id 2 with length (100175, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:0, threshold:0.46600162982940674, from bucket_id:1's shape (306361, 2), to bucket id 3 with length (187005, 2) & bucket id 4 with length (119356, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.16817931830883026, from bucket_id:3's shape (187005, 2), to bucket id 7 with length (162393, 2) & bucket id 8 with length (24612, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.05442429706454277, from bucket_id:7's shape (162393, 2), to bucket id 15 with length (153371, 2) & bucket id 16 with length (9022, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.32497042417526245, from bucket_id:8's shape (24612, 2), to bucket id 17 with length (11622, 2) & bucket id 18 with length (12990, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:0.9021090269088745, from bucket_id:4's shape (119356, 2), to bucket id 9 with length (66218, 2) & bucket id 10 with length (53138, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.6962770223617554, from bucket_id:9's shape (66218, 2), to bucket id 19 with length (31412, 2) & bucket id 20 with length (34806, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# ...
# bucket splitted with dim:1, threshold:0.10853978246450424, from bucket_id:7's shape (139363, 2), to bucket id 15 with length (108124, 2) & bucket id 16 with length (31239, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.6953322887420654, from bucket_id:8's shape (55070, 2), to bucket id 17 with length (27746, 2) & bucket id 18 with length (27324, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:1, threshold:0.5787659883499146, from bucket_id:4's shape (81882, 2), to bucket id 9 with length (52683, 2) & bucket id 10 with length (29199, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.2711695432662964, from bucket_id:9's shape (52683, 2), to bucket id 19 with length (43663, 2) & bucket id 20 with length (9020, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:0.35454636812210083, from bucket_id:10's shape (29199, 2), to bucket id 21 with length (9444, 2) & bucket id 22 with length (19755, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:1, threshold:1.8134491443634033, from bucket_id:2's shape (130221, 2), to bucket id 5 with length (93262, 2) & bucket id 6 with length (36959, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:1, threshold:1.2520174980163574, from bucket_id:5's shape (93262, 2), to bucket id 11 with length (39395, 2) & bucket id 12 with length (53867, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:1, threshold:1.0360817909240723, from bucket_id:11's shape (39395, 2), to bucket id 23 with length (20676, 2) & bucket id 24 with length (18719, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:1, threshold:1.5005168914794922, from bucket_id:12's shape (53867, 2), to bucket id 25 with length (33271, 2) & bucket id 26 with length (20596, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:1, threshold:2.9559879302978516, from bucket_id:6's shape (36959, 2), to bucket id 13 with length (32625, 2) & bucket id 14 with length (4334, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:1, threshold:2.319913148880005, from bucket_id:13's shape (32625, 2), to bucket id 27 with length (26302, 2) & bucket id 28 with length (6323, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:1, threshold:3.6297998428344727, from bucket_id:14's shape (4334, 2), to bucket id 29 with length (1605, 2) & bucket id 30 with length (2729, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:1.604114055633545, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (324355, 2) & bucket id 2 with length (82181, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:0, threshold:0.5599274635314941, from bucket_id:1's shape (324355, 2), to bucket id 3 with length (241532, 2) & bucket id 4 with length (82823, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.188188374042511, from bucket_id:3's shape (241532, 2), to bucket id 7 with length (216336, 2) & bucket id 8 with length (25196, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.06096051633358002, from bucket_id:7's shape (216336, 2), to bucket id 15 with length (208217, 2) & bucket id 16 with length (8119, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.38118085265159607, from bucket_id:8's shape (25196, 2), to bucket id 17 with length (13949, 2) & bucket id 18 with length (11247, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:1.1324609518051147, from bucket_id:4's shape (82823, 2), to bucket id 9 with length (50178, 2) & bucket id 10 with length (32645, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.8462164998054504, from bucket_id:9's shape (50178, 2), to bucket id 19 with length (18807, 2) & bucket id 20 with length (31371, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:1.368281364440918, from bucket_id:10's shape (32645, 2), to bucket id 21 with length (13670, 2) & bucket id 22 with length (18975, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:2.9913365840911865, from bucket_id:2's shape (82181, 2), to bucket id 5 with length (45822, 2) & bucket id 6 with length (36359, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:2.267813205718994, from bucket_id:5's shape (45822, 2), to bucket id 11 with length (28537, 2) & bucket id 12 with length (17285, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:0, threshold:1.922755241394043, from bucket_id:11's shape (28537, 2), to bucket id 23 with length (17945, 2) & bucket id 24 with length (10592, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:0, threshold:2.636976718902588, from bucket_id:12's shape (17285, 2), to bucket id 25 with length (7859, 2) & bucket id 26 with length (9426, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:4.246383190155029, from bucket_id:6's shape (36359, 2), to bucket id 13 with length (28248, 2) & bucket id 14 with length (8111, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:3.519968271255493, from bucket_id:13's shape (28248, 2), to bucket id 27 with length (18110, 2) & bucket id 28 with length (10138, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:17.90493392944336, from bucket_id:14's shape (8111, 2), to bucket id 29 with length (8098, 2) & bucket id 30 with length (13, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:0.6210253238677979, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (290470, 2) & bucket id 2 with length (116066, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:0, threshold:0.2029067873954773, from bucket_id:1's shape (290470, 2), to bucket id 3 with length (221133, 2) & bucket id 4 with length (69337, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.06801787763834, from bucket_id:3's shape (221133, 2), to bucket id 7 with length (185229, 2) & bucket id 8 with length (35904, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.02288929745554924, from bucket_id:7's shape (185229, 2), to bucket id 15 with length (171697, 2) & bucket id 16 with length (13532, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.13390697538852692, from bucket_id:8's shape (35904, 2), to bucket id 17 with length (19209, 2) & bucket id 18 with length (16695, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:0.4252994656562805, from bucket_id:4's shape (69337, 2), to bucket id 9 with length (47357, 2) & bucket id 10 with length (21980, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.3019329607486725, from bucket_id:9's shape (47357, 2), to bucket id 19 with length (21105, 2) & bucket id 20 with length (26252, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:0.5334481000900269, from bucket_id:10's shape (21980, 2), to bucket id 21 with length (9317, 2) & bucket id 22 with length (12663, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:1.2174171209335327, from bucket_id:2's shape (116066, 2), to bucket id 5 with length (73654, 2) & bucket id 6 with length (42412, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:0.87109375, from bucket_id:5's shape (73654, 2), to bucket id 11 with length (31440, 2) & bucket id 12 with length (42214, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:0, threshold:0.734134316444397, from bucket_id:11's shape (31440, 2), to bucket id 23 with length (16459, 2) & bucket id 24 with length (14981, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:0, threshold:1.0220160484313965, from bucket_id:12's shape (42214, 2), to bucket id 25 with length (24571, 2) & bucket id 26 with length (17643, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:1.6455398797988892, from bucket_id:6's shape (42412, 2), to bucket id 13 with length (29499, 2) & bucket id 14 with length (12913, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:1.4236687421798706, from bucket_id:13's shape (29499, 2), to bucket id 27 with length (17015, 2) & bucket id 28 with length (12484, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:1.9951245784759521, from bucket_id:14's shape (12913, 2), to bucket id 29 with length (9973, 2) & bucket id 30 with length (2940, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0
# start split function with bucket_id:0, max_depth:4
# bucket splitted with dim:0, threshold:0.7247926592826843, from bucket_id:0's shape (406536, 2), to bucket id 1 with length (312903, 2) & bucket id 2 with length (93633, 2)
# start split function with bucket_id:1, max_depth:3
# bucket splitted with dim:0, threshold:0.2545246481895447, from bucket_id:1's shape (312903, 2), to bucket id 3 with length (272306, 2) & bucket id 4 with length (40597, 2)
# start split function with bucket_id:3, max_depth:2
# bucket splitted with dim:0, threshold:0.07874345779418945, from bucket_id:3's shape (272306, 2), to bucket id 7 with length (246726, 2) & bucket id 8 with length (25580, 2)
# start split function with bucket_id:7, max_depth:1
# bucket splitted with dim:0, threshold:0.026231246069073677, from bucket_id:7's shape (246726, 2), to bucket id 15 with length (235049, 2) & bucket id 16 with length (11677, 2)
# start split function with bucket_id:15, max_depth:0
# start split function with bucket_id:16, max_depth:0
# start split function with bucket_id:8, max_depth:1
# bucket splitted with dim:0, threshold:0.1626468300819397, from bucket_id:8's shape (25580, 2), to bucket id 17 with length (14947, 2) & bucket id 18 with length (10633, 2)
# start split function with bucket_id:17, max_depth:0
# start split function with bucket_id:18, max_depth:0
# start split function with bucket_id:4, max_depth:2
# bucket splitted with dim:0, threshold:0.4871646761894226, from bucket_id:4's shape (40597, 2), to bucket id 9 with length (19509, 2) & bucket id 10 with length (21088, 2)
# start split function with bucket_id:9, max_depth:1
# bucket splitted with dim:0, threshold:0.3665069341659546, from bucket_id:9's shape (19509, 2), to bucket id 19 with length (9348, 2) & bucket id 20 with length (10161, 2)
# start split function with bucket_id:19, max_depth:0
# start split function with bucket_id:20, max_depth:0
# start split function with bucket_id:10, max_depth:1
# bucket splitted with dim:0, threshold:0.6046265959739685, from bucket_id:10's shape (21088, 2), to bucket id 21 with length (10272, 2) & bucket id 22 with length (10816, 2)
# start split function with bucket_id:21, max_depth:0
# start split function with bucket_id:22, max_depth:0
# start split function with bucket_id:2, max_depth:3
# bucket splitted with dim:0, threshold:1.8075249195098877, from bucket_id:2's shape (93633, 2), to bucket id 5 with length (76803, 2) & bucket id 6 with length (16830, 2)
# start split function with bucket_id:5, max_depth:2
# bucket splitted with dim:0, threshold:1.1978893280029297, from bucket_id:5's shape (76803, 2), to bucket id 11 with length (49172, 2) & bucket id 12 with length (27631, 2)
# start split function with bucket_id:11, max_depth:1
# bucket splitted with dim:0, threshold:0.9569538831710815, from bucket_id:11's shape (49172, 2), to bucket id 23 with length (26074, 2) & bucket id 24 with length (23098, 2)
# start split function with bucket_id:23, max_depth:0
# start split function with bucket_id:24, max_depth:0
# start split function with bucket_id:12, max_depth:1
# bucket splitted with dim:0, threshold:1.4659806489944458, from bucket_id:12's shape (27631, 2), to bucket id 25 with length (15716, 2) & bucket id 26 with length (11915, 2)
# start split function with bucket_id:25, max_depth:0
# start split function with bucket_id:26, max_depth:0
# start split function with bucket_id:6, max_depth:2
# bucket splitted with dim:0, threshold:2.5757505893707275, from bucket_id:6's shape (16830, 2), to bucket id 13 with length (10155, 2) & bucket id 14 with length (6675, 2)
# start split function with bucket_id:13, max_depth:1
# bucket splitted with dim:0, threshold:2.1605496406555176, from bucket_id:13's shape (10155, 2), to bucket id 27 with length (5270, 2) & bucket id 28 with length (4885, 2)
# start split function with bucket_id:27, max_depth:0
# start split function with bucket_id:28, max_depth:0
# start split function with bucket_id:14, max_depth:1
# bucket splitted with dim:0, threshold:3.4796435832977295, from bucket_id:14's shape (6675, 2), to bucket id 29 with length (6219, 2) & bucket id 30 with length (456, 2)
# start split function with bucket_id:29, max_depth:0
# start split function with bucket_id:30, max_depth:0

# %%
inputTensor = torch.from_numpy(input).float().to(arg_settings.Device)
# inputTensor = inputTensor[:100]
layerJB.compare_outputs(inputTensor)
# Out:
# NMSE between matmul and dm for nimbus_linear_3: 0.020570790395140648
# NMSE between matmul and maddness for nimbus_linear_3: 0.020570790395140648

# %%
nimbusLinear = modules.NimbusLinear(32, 3, False, codeblockCount=16, treeDepth=4)
nimbusLinear.weight.data = weight
nimbusLinear.learn_maddness_params(input)
nimbusLinear.compare_outputs(inputTensor)
# Out:
# start nimbus linear init, in_features: 32 out_features: 3 bias: False state: 1 codeblockCount: 16 treeDepth: 4
# Learning progress (406536, 32)-16-16: 1/16 (2.707 GB)
# Learning progress (406536, 32)-16-16: 2/16 (2.721 GB)
# Learning progress (406536, 32)-16-16: 3/16 (2.721 GB)
# Learning progress (406536, 32)-16-16: 4/16 (2.721 GB)
# Learning progress (406536, 32)-16-16: 5/16 (2.721 GB)
# Learning progress (406536, 32)-16-16: 6/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 7/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 8/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 9/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 10/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 11/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 12/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 13/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 14/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 15/16 (2.744 GB)
# Learning progress (406536, 32)-16-16: 16/16 (2.752 GB)
# X_error mse / X mean squared value:  0.03835197 0.036666162 0.9560437 0.5298427
# Error to Original squared diff 0.9193784
# (16, 4, 11) float32 (406536, 32) float32
# {'alpha': 1, 'copy_X': False, 'fit_intercept': False, 'max_iter': None, 'normalize': 'deprecated', 'positive': False, 'random_state': None, 'solver': 'auto', 'tol': 0.001}
# After Ridge regression (406536, 32)-16-16(3.823 GB)
# NMSE between matmul and dm for nimbus_linear_4: 0.024369454011321068
# NMSE between matmul and maddness for nimbus_linear_4: 0.02905021607875824
